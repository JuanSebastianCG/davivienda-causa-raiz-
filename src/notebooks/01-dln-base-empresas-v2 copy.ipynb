# %% [markdown]
# ### Librerias

# %%
import sys
import pandas as pd

sys.path.append("../utils")
from figures import (
    convert_columns_names,
    process_product_column,
    plot_bar_percentage,
    plot_bar_percentage2,
    plot_weekly_distribution,
    plot_weekday_distribution,
    plot_pie_chart,
    plot_stacked_barh,
    plot_joint_distribution,
    plot_linear_weekday_distribution
)
from utils import change_values

import warnings

warnings.filterwarnings("ignore")

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Empresas

# %%
df = pd.read_excel("../../results/empresas_abril_v14-06-24.xlsx")
df = convert_columns_names(df)
df = process_product_column(df)
df = change_values(df, "medio_de_radicacion", 0, "Otros")
df = change_values(df, "medio_de_respuesta", 0, "Otros")

# %%
plot_bar_percentage2(df, "subcategory")

# %%
plot_weekly_distribution(df, "fecha_apertura")
# Out:
# 2024-06-17 10:11:39,061 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-06-17 10:11:39,067 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
index_order = [
    "Error Transacción",
    "Cobro No Autorizado",
    "Fraude Virtual",
    "Movimiento Desconocido",
    "Solicitud Reporte",
    "Solicitud Certificación",
    "Solicitud Aclaración",
    "Solicitud Información",
    "Creación Producto Servicio",
    "Causa No Identificada",
]
plot_weekday_distribution(df, "fecha_apertura", "subcategory", )

# %%
index_order = [
    "Error Transacción",
    "Cobro No Autorizado",
    "Fraude Virtual",
    "Movimiento Desconocido",
    "Solicitud Reporte",
    "Solicitud Certificación",
    "Solicitud Aclaración",
    "Solicitud Información",
    "Creación Producto Servicio",
    "Causa No Identificada",
]
plot_linear_weekday_distribution(df, "fecha_apertura", "subcategory",  threshold=2)

# %%
order = [
    "BANCA PRIVADA",
    "PREMIUM PLUS",
    "PREMIUM",
    "INCLUSIÓN FINANCIERA",
    "CLASICO",
    "NO INFORMADO",
]

index_order = [
    "Error Transacción",
    "Cobro No Autorizado",
    "Fraude Virtual",
    "Movimiento Desconocido",
    "Solicitud Reporte",
    "Solicitud Certificación",
    "Solicitud Aclaración",
    "Solicitud Información",
    "Creación Producto Servicio",
    "Causa No Identificada",
]

# Ejemplo de uso
plot_joint_distribution(
    df,
    x="segmento_comercial",
    y="causa_raiz",
    x_order=order,
    y_order=index_order,
    label_rotation=45,
    y_label="Causa Raíz",
    x_label="Segmento Comercial",
)

# %%
index_order = [
    "Error Transacción",
    "Cobro No Autorizado",
    "Fraude Virtual",
    "Movimiento Desconocido",
    "Solicitud Reporte",
    "Solicitud Certificación",
    "Solicitud Aclaración",
    "Solicitud Información",
    "Creación Producto Servicio",
    "Causa No Identificada",
]

plot_joint_distribution(
    df,
    x="medio_de_radicacion",
    y="causa_raiz",
    x_order=None,
    y_order=index_order,
    label_rotation=45,
    y_label="Causa Raíz",
    x_label="Medio de Radicación",
)

# %%
index_order = [
    "Error Transacción",
    "Cobro No Autorizado",
    "Fraude Virtual",
    "Movimiento Desconocido",
    "Solicitud Reporte",
    "Solicitud Certificación",
    "Solicitud Aclaración",
    "Solicitud Información",
    "Creación Producto Servicio",
    "Causa No Identificada",
]

col_order = [
    "CREDITO",
    "LEASING",
    "LEASING HABITACIONAL",
    "CREDIEXPRESS FIJO",
    "TARJETA DE CREDITO",
    "CUENTA CORRIENTE",
    "CUENTA DE AHORROS DAMAS",
    "CUENTA DE AHORROS FIJO DIARIO",
    "Otros",
]

plot_joint_distribution(
    df,
    x="producto_",
    y="causa_raiz",
    x_order=col_order,
    y_order=index_order,
    label_rotation=45,
    y_label="Causa Raíz",
    x_label="Producto",
)

# %%
order = [
    "CREDITO",
    "LEASING",
    "LEASING HABITACIONAL",
    "CREDIEXPRESS FIJO",
    "TARJETA DE CREDITO",
    "CUENTA CORRIENTE",
    "CUENTA DE AHORROS DAMAS",
    "CUENTA DE AHORROS FIJO DIARIO",
    "Otros",
]

plot_joint_distribution(
    df,
    x="medio_de_radicacion",
    y="producto_",
    x_order=None,
    y_order=order,
    label_rotation=45,
    y_label="Producto",
    x_label="Medio de Radicación",
)

# %%
plot_pie_chart(df, "tipo", 5, n_colors=4, legend_ncol=1, num_registros=True)

# %%
plot_stacked_barh(
    df,
    "tipo",
    "causa_raiz",
    xlim=(0, 175),
    remove_axes_lines=True,
    rounded_bars=True,
    n_colors=4,
    threshold=100,
)

# %%
plot_stacked_barh(
    df,
    "tipo",
    "producto_",
    xlim=(0, 175),
    remove_axes_lines=True,
    rounded_bars=True,
    n_colors=4,
    threshold=101,
)

# %%
plot_bar_percentage(df, "des2", percentage=80)

# %%
index_order = [
    "Error Transacción",
    "Cobro No Autorizado",
    "Fraude Virtual",
    "Movimiento Desconocido",
    "Solicitud Reporte",
    "Solicitud Certificación",
    "Solicitud Aclaración",
    "Solicitud Información",
    "Creación Producto Servicio",
    "Causa No Identificada",
]

plot_joint_distribution(
    df,
    x="causa_raiz",
    y="des2",
    x_order=index_order,
    y_order=None,
    label_rotation=45,
    y_label="Departamento de Radicación",
    x_label="Causa Raíz",
    top_y=10,
    fontsize=9,
)

# %%
plot_pie_chart(
    df, "segmento_comercial", 2, n_colors=6, legend_ncol=1, num_registros=True
)

# %%
plot_pie_chart(
    df, "medio_de_radicacion", 3, n_colors=7, legend_ncol=1, num_registros=True
)

# %%
plot_pie_chart(df, "producto_", 5, n_colors=6, legend_ncol=1, num_registros=True)

# %%
plot_joint_distribution(
    df,
    x="medio_de_respuesta",
    y="medio_de_radicacion",
    x_order=None,
    y_order=None,
    label_rotation=45,
    y_label="Medio de Radicación",
    x_label="Medio de Respuesta",
)

# %%
index_order = [
    "Error Transacción",
    "Cobro No Autorizado",
    "Fraude Virtual",
    "Movimiento Desconocido",
    "Solicitud Reporte",
    "Solicitud Certificación",
    "Solicitud Aclaración",
    "Solicitud Información",
    "Creación Producto Servicio",
    "Causa No Identificada",
]

plot_joint_distribution(
    df,
    x="causa_raiz",
    y="motivo",
    x_order=index_order,
    y_order=None,
    label_rotation=45,
    y_label="Motivo",
    x_label="Causa Raíz",
    top_y=9,
)
